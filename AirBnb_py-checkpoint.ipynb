# %%
import pandas as pd
import seaborn as sns
import matplotlib.colors as colors
from matplotlib import pyplot as plt
from sklearn import metrics
import numpy as np


# linear
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# random forest
from sklearn import tree
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import make_scorer
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor


import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Data importing

# %%
df = pd.read_csv('./Airbnb_2022.csv')

# %%
df.head()
# Out:
#      id                                      name  host_id  host_name  \
# 0  2595                     Skylit Midtown Castle     2845   Jennifer
# 1  5121                           BlissArtsSpace!     7356      Garon
# 2  5136  Spacious Brooklyn Duplex, Patio + Garden     7378    Rebecca
# 3  5178          Large Furnished Room Near B'way　     8967   Shunichi
# 4  5203        Cozy Clean Guest Room - Family Apt     7490  MaryEllen
#
#   neighbourhood_group       neighbourhood  latitude  longitude  \
# 0           Manhattan             Midtown  40.75356  -73.98559
# 1            Brooklyn  Bedford-Stuyvesant  40.68535  -73.95512
# 2            Brooklyn         Sunset Park  40.66265  -73.99454
# 3           Manhattan             Midtown  40.76457  -73.98317
# 4           Manhattan     Upper West Side  40.80380  -73.96751
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0  Entire home/apt    150              30                 48  2019-11-04
# 1     Private room     60              30                 50  2019-12-02
# 2  Entire home/apt    275               5                  2  2021-08-08
# 3     Private room     68               2                520  2022-02-18
# 4     Private room     75               2                118  2017-07-21
#
#    reviews_per_month  calculated_host_listings_count  availability_365  \
# 0               0.32                               3               334
# 1               0.32                               2               365
# 2               0.02                               1               201
# 3               3.33                               1               154
# 4               0.77                               1                 0
#
#    number_of_reviews_ltm license
# 0                      0     NaN
# 1                      0     NaN
# 2                      1     NaN
# 3                     46     NaN
# 4                      0     NaN

# %%
df.isnull().sum()
# Out:
# id                                    0
# name                                 14
# host_id                               0
# host_name                            87
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                        8974
# reviews_per_month                  8974
# calculated_host_listings_count        0
# availability_365                      0
# number_of_reviews_ltm                 0
# license                           37630
# dtype: int64

# %% [markdown]
# Now we saw that we have alot of null elements, lets fill them.

# %% [markdown]
# # Cleaning Data

# %%
df.fillna({'reviews_per_month':0}, inplace=True)
df.fillna({'name':"NoName"}, inplace=True)
df.fillna({'host_name':"NoName"}, inplace=True)
df.fillna({'last_review':"NotReviewed"}, inplace=True)
df.fillna({'license':"NoLicense"}, inplace=True)

# %%
df.isnull().sum()
# Out:
# id                                0
# name                              0
# host_id                           0
# host_name                         0
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# last_review                       0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# number_of_reviews_ltm             0
# license                           0
# dtype: int64

# %% [markdown]
# All the fileds fiiled, lets check the price field

# %%
df['price'].describe()
# Out:
# count    37631.000000
# mean       166.224682
# std        306.763703
# min          0.000000
# 25%         68.000000
# 50%        112.000000
# 75%        180.000000
# max      10000.000000
# Name: price, dtype: float64

# %% [markdown]
# Check price 0, if exist -> delete

# %%
price_zero = df['price'][df['price'] == 0]
price_zero.count()
# Out:
# 37

# %%
df = df[df['price'] != 0]

# %% [markdown]
# The price is between 0 to 10,000, lets check the less then 800 price

# %%
hist_lower_1000 = df["price"][df["price"]<800].hist()

# %% [markdown]
# we can see that most airbnb apartments are less then 800, lets delete them

# %%
df=df[df["price"]<800]

# %% [markdown]
# There are 223 unique neighbourhoods in NYC as per this data set. Most listings are in Bedford-Stuyvesant

# %%
df['neighbourhood'].value_counts()
# Out:
# Bedford-Stuyvesant    2813
# Williamsburg          2370
# Harlem                1831
# Hell's Kitchen        1678
# Bushwick              1651
#                       ...
# Neponsit                 1
# Bull's Head              1
# Westerleigh              1
# South Beach              1
# Woodrow                  1
# Name: neighbourhood, Length: 223, dtype: int64

# %% [markdown]
# lets check the neighbourhood that more then 200

# %%
dfnh = df.groupby("neighbourhood").filter(lambda x: x['neighbourhood'].count() > 200)
len(dfnh)
# Out:
# 30506

# %% [markdown]
# Most data is convert 30,000 / 37000
#
# Lets look at neighbourhood groups

# %%
df['neighbourhood_group'].describe()
# Out:
# count         36999
# unique            5
# top       Manhattan
# freq          15613
# Name: neighbourhood_group, dtype: object

# %% [markdown]
# There are 5 uniqe neighbourhood group, lets check how many apartments has each neighbourhood group

# %%
df['neighbourhood_group'].value_counts()
# Out:
# Manhattan        15613
# Brooklyn         14250
# Queens            5609
# Bronx             1195
# Staten Island      332
# Name: neighbourhood_group, dtype: int64

# %% [markdown]
# Lets check the mean price for each neighbourhood

# %%
ng_price = df.groupby("neighbourhood_group")["price"].mean()
ng_price
# Out:
# neighbourhood_group
# Bronx             98.117992
# Brooklyn         124.842807
# Manhattan        176.679306
# Queens           101.873953
# Staten Island    113.822289
# Name: price, dtype: float64

# %% [markdown]
# we can that the data is ok and Manhattan is the most expensive and Bronx is the least expensive place to live

# %% [markdown]
# Lets see this data in scatter plot

# %%
plott = df.plot.scatter(x="neighbourhood_group",y="price",colormap = 'viridis')

# %% [markdown]
# Here we can note that Brooklyn and Manhattan tend to have more expensive listings

# %%
df["room_type"].describe()
df["room_type"].value_counts()
# Out:
# Entire home/apt    19949
# Private room       16346
# Shared room          558
# Hotel room           146
# Name: room_type, dtype: int64

# %%
df.groupby("room_type")["price"].mean()
# Out:
# room_type
# Entire home/apt    189.573061
# Hotel room         262.945205
# Private room        85.811819
# Shared room         73.641577
# Name: price, dtype: float64

# %% [markdown]
# Entire home / apt is the most expensive room type

# %%
### Lets see the distributuion of price and neighbourhood group. 
# plott=sns.catplot(x="neighbourhood_group",y="price",hue="room_type", kind="swarm", data=df)
# plott

# %% [markdown]
# after we saw that the room type affects on the price, lets check the name coulmn (listing description). lets check the name length.

# %%
name_length_df = df["name"].str.len()
df["name_length"] = name_length_df
df["name_length"]
# Out:
# 0        21
# 1        15
# 2        40
# 3        32
# 4        34
#          ..
# 37626    39
# 37627    26
# 37628    26
# 37629    33
# 37630    42
# Name: name_length, Length: 36999, dtype: int64

# %% [markdown]
# lets check if the name column length effects on number of reviews

# %%
ax = df.plot.scatter(x='name_length',
                    y='number_of_reviews')

# %% [markdown]
# name length < 50 has more reviews, now lets check the price and name length

# %%
ax = df[df["name_length"] < 50].plot.scatter(x="price",
                    y='name_length')

# %% [markdown]
# Analysing the minimum nights

# %%
df['minimum_nights'].describe()
# Out:
# count    36999.000000
# mean        20.525393
# std         29.155365
# min          1.000000
# 25%          2.000000
# 50%         30.000000
# 75%         30.000000
# max       1250.000000
# Name: minimum_nights, dtype: float64

# %% [markdown]
# there are minimum nights between 1 to 1250 and the mean is < 20.6

# %%
df['minimum_nights'].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# the most listening is < 100, lets get a closer look

# %%
df['minimum_nights'][df['minimum_nights'] < 100 ].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# We see that the most is under 40

# %%
df['minimum_nights'][df['minimum_nights'] > 40 ].count()
# Out:
# 987

# %%
sns.scatterplot(df['price'],df['minimum_nights'])
# Out:
# <AxesSubplot:xlabel='price', ylabel='minimum_nights'>

# %%
sns.boxplot(df['minimum_nights'])
# Out:
# <AxesSubplot:xlabel='minimum_nights'>

# %% [markdown]
# lets change all minimum nights that > 60 to 60

# %%
df['minimum_nights'][df['minimum_nights'] > 60 ] = 60

# %%
#check
df['minimum_nights'].describe()
# Out:
# count    36999.000000
# mean        18.618530
# std         14.997088
# min          1.000000
# 25%          2.000000
# 50%         30.000000
# 75%         30.000000
# max         60.000000
# Name: minimum_nights, dtype: float64

# %% [markdown]
# lets look at reviews per month

# %%
df['reviews_per_month'].describe()
# Out:
# count    36999.000000
# mean         0.803864
# std          1.635920
# min          0.000000
# 25%          0.010000
# 50%          0.200000
# 75%          1.000000
# max         90.000000
# Name: reviews_per_month, dtype: float64

# %% [markdown]
# check if reviews per mouth effect on price

# %%
#most of the reviews_per_month <5 lets check them
rpm_df = df[df["reviews_per_month"]<5]
rpm_df.plot.scatter(x = 'reviews_per_month',
                y = 'price')
# Out:
# <AxesSubplot:xlabel='reviews_per_month', ylabel='price'>

# %%
rpm_df = rpm_df[rpm_df["reviews_per_month"] == 0]
len(rpm_df)
# Out:
# 8712

# %%
rpm_df["price"].hist()
# Out:
# <AxesSubplot:>

# %%
df["reviews_per_month"].corr(df["price"])
# Out:
# -0.019499405996484753

# %% [markdown]
# there are no strongly corralation between reviews per month and price
#
# lets look at the availability

# %%
df['availability_365'].describe()
# Out:
# count    36999.000000
# mean       128.695776
# std        140.403678
# min          0.000000
# 25%          0.000000
# 50%         65.000000
# 75%        274.000000
# max        365.000000
# Name: availability_365, dtype: float64

# %% [markdown]
# lets look how many rows have 0 availability

# %%
sns.boxplot(df["availability_365"])
# Out:
# <AxesSubplot:xlabel='availability_365'>

# %% [markdown]
# no outliers

# %%
df.plot.scatter(x = "availability_365",y = 'price')
# Out:
# <AxesSubplot:xlabel='availability_365', ylabel='price'>

# %% [markdown]
# # EDA

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(x='longitude', y='latitude', hue='neighbourhood_group',s=20, data=df)
# Out:
# <AxesSubplot:xlabel='longitude', ylabel='latitude'>

# %%
### Plotting correlation matrix 
corr = df.corr(method='pearson')
plt.figure(figsize=(15,8))
sns.heatmap(corr, annot=True)
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365', 'number_of_reviews_ltm', 'license', 'name_length'],
#       dtype='object')

# %% [markdown]
# lets drop the columns that not usful in train and prediction

# %%
df.drop(["name",'last_review',
         "latitude",'longitude',
         'host_id','host_name',
         'id','license','number_of_reviews_ltm','reviews_per_month'], axis=1, inplace=True)

# %%
df.dtypes
# Out:
# neighbourhood_group               object
# neighbourhood                     object
# room_type                         object
# price                              int64
# minimum_nights                     int64
# number_of_reviews                  int64
# calculated_host_listings_count     int64
# availability_365                   int64
# name_length                        int64
# dtype: object

# %% [markdown]
# # Mechine Learning

# %% [markdown]
# # Start with Linear Regression

# %%
dataset_onehot1 = pd.get_dummies(df, columns=['neighbourhood_group',"room_type"], prefix = ['ng',"rt"],drop_first=True)
dataset_onehot1.drop(["neighbourhood"], axis=1, inplace=True)
X1= dataset_onehot1.loc[:, dataset_onehot1.columns != 'price']
Y1 = dataset_onehot1["price"]
x_train1, x_test1, y_train1, y_test1 = train_test_split(X1, Y1, test_size=0.20, random_state=42)

# %%
dataset_onehot1.shape
# Out:
# (36999, 13)

# %%
### Fitting Linear regression
reg1 = LinearRegression().fit(x_train1, y_train1)

# %%
### R squared value
reg1.score(x_train1, y_train1)
# Out:
# 0.2954199877360315

# %%
# let's look inside the model
print("b1:",reg1.coef_)
print("b0:",reg1.intercept_)
# Out:
# b1: [-1.01281955e+00 -1.43701705e-01  9.68662066e-02  5.03717933e-02
#   6.98473480e-01  2.78809873e+01  6.80517079e+01  1.04248366e+01
#  -5.70655709e+00  4.26759658e+01 -9.64357602e+01 -1.12387889e+02]
# b0: 133.96353677785098

# %%
### Predicting 
y_pred1 = reg1.predict(x_test1)

# %%
Coeff1 = pd.DataFrame(columns=["Variable","Coefficient"])
Coeff1["Variable"]=x_train1.columns
Coeff1["Coefficient"]=reg1.coef_
Coeff1.sort_values("Coefficient")
# Out:
#                           Variable  Coefficient
# 11                  rt_Shared room  -112.387889
# 10                 rt_Private room   -96.435760
# 8                 ng_Staten Island    -5.706557
# 0                   minimum_nights    -1.012820
# 1                number_of_reviews    -0.143702
# 3                 availability_365     0.050372
# 2   calculated_host_listings_count     0.096866
# 4                      name_length     0.698473
# 7                        ng_Queens    10.424837
# 5                      ng_Brooklyn    27.880987
# 9                    rt_Hotel room    42.675966
# 6                     ng_Manhattan    68.051708

# %% [markdown]
# lets try to clean more our data

# %%
sns.violinplot(df["room_type"],df["price"])
# Out:
# <AxesSubplot:xlabel='room_type', ylabel='price'>

# %% [markdown]
# As can be seen, there are alot outlires existing so we are cleaning the data for each room type separately

# %%
df2=df[df['room_type'] =='Private room'][df["price"]<180][df["price"]>20]
df3=df[df['room_type'] =='Shared room'][df["price"]<120][df["price"]>10]
df4=df[df['room_type'] =='Entire home/apt'][df["price"]>40][df["price"]<230]
df5=df[df['room_type'] =='Hotel room'][df["price"]<200]
df2=df2.append(df3, ignore_index = True)
df2=df2.append(df4, ignore_index = True)
df2=df2.append(df5, ignore_index = True)
df=df2
sns.violinplot(df["room_type"],df["price"])
# Out:
# <AxesSubplot:xlabel='room_type', ylabel='price'>

# %% [markdown]
# looking better, there are less oulier.

# %%
dataset_onehot2 = pd.get_dummies(df, columns=['neighbourhood_group',"room_type"], prefix = ['ng',"rt"],drop_first=True)
dataset_onehot2.drop(["neighbourhood"], axis=1, inplace=True)
X2= dataset_onehot2.loc[:, dataset_onehot1.columns != 'price']
Y2 = dataset_onehot2["price"]
x_train2, x_test2, y_train2, y_test2 = train_test_split(X2, Y2, test_size=0.20, random_state=42)
### Fitting Linear regression
reg2 = LinearRegression().fit(x_train2, y_train2)

# %%
### R squared value
reg2.score(x_train2, y_train2)
# Out:
# 0.5006352672345016

# %%
# let's look inside the model
print("b1:",reg2.coef_)
print("b0:",reg2.intercept_)
# Out:
# b1: [-3.66114565e-01 -2.33711835e-02 -8.98055451e-02  1.73344784e-02
#   9.26841141e-02  1.63961388e+01  3.41105898e+01  7.23174656e+00
#  -3.45076997e-01  1.31726852e+01 -6.38622982e+01 -8.67621142e+01]
# b0: 119.43302702557833

# %%
### Predicting 
y_pred2 = reg2.predict(x_test2)

Coeff2 = pd.DataFrame(columns=["Variable","Coefficient"])
Coeff2["Variable"]=x_train2.columns
Coeff2["Coefficient"]=reg2.coef_
Coeff2.sort_values("Coefficient")
# Out:
#                           Variable  Coefficient
# 11                  rt_Shared room   -86.762114
# 10                 rt_Private room   -63.862298
# 0                   minimum_nights    -0.366115
# 8                 ng_Staten Island    -0.345077
# 2   calculated_host_listings_count    -0.089806
# 1                number_of_reviews    -0.023371
# 3                 availability_365     0.017334
# 4                      name_length     0.092684
# 7                        ng_Queens     7.231747
# 9                    rt_Hotel room    13.172685
# 5                      ng_Brooklyn    16.396139
# 6                     ng_Manhattan    34.110590

# %%
df_pred2 = pd.DataFrame({'Actual': y_test2, 'Predicted': y_pred2})
df_pred2
# Out:
#        Actual   Predicted
# 25145      99  132.026815
# 12831     161   92.143174
# 1043       90   77.056625
# 7801       42   82.755490
# 24497     120  130.650204
# ...       ...         ...
# 13572      80   71.764109
# 18834      70  127.165710
# 5437       37   75.152020
# 17402      77  144.687587
# 24151     163  158.020536
#
# [6200 rows x 2 columns]

# %%
plt.scatter(x=y_test2,y=y_pred2,c='g',marker='s')
plt.plot(y_pred2,y_pred2,c='b',linewidth=3)

# %% [markdown]
# # Model Interpretation

# %% [markdown]
# # Lasso Regression

# %%
from sklearn.linear_model import Lasso
dataset_onehot2 = pd.get_dummies(df,
                                 columns=['neighbourhood_group',"neighbourhood","room_type"], 
                                 prefix = ['ng',"nh","rt"],
                                 drop_first=True)
XL1 = dataset_onehot2.loc[:, dataset_onehot2.columns != 'price']
YL1 = dataset_onehot2["price"]
x_trainL11, x_testL11, y_trainL11, y_testL11 = train_test_split(XL1, YL1, test_size=0.20, random_state=42)
regL1 = Lasso(alpha=0.01)

# %%
regL1.fit(x_trainL11, y_trainL11) 
print(regL1.score(x_trainL11, y_trainL11))
# Out:
# 0.5537314108788236

# %%
dataset_onehot2.shape
# Out:
# (30998, 232)

# %%
CoeffLS1 = pd.DataFrame(columns=["Variable","Coefficients"])
CoeffLS1["Variable"]=x_trainL11.columns
CoeffLS1["Coefficients"]=regL1.coef_
CoeffLS1.sort_values("Coefficients", ascending = False)
# Out:
#                   Variable  Coefficients
# 6             ng_Manhattan     40.117678
# 32     nh_Brooklyn Heights     32.822013
# 26          nh_Boerum Hill     27.337271
# 38      nh_Carroll Gardens     26.051887
# 81   nh_Financial District     25.730014
# ..                     ...           ...
# 103              nh_Harlem    -22.760888
# 214  nh_Washington Heights    -33.526028
# 112              nh_Inwood    -37.833861
# 229        rt_Private room    -61.008068
# 230         rt_Shared room    -84.005799
#
# [231 rows x 2 columns]
